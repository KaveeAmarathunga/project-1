# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.optimizers import RMSprop
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
import cv2
import os

from google.colab import drive
drive.mount('/content/drive')

os.chdir("/content/drive/My Drive/project 1/")
os.getcwd()

img = image.load_img("training/D/da 1.jpeg")

plt.imshow(img)

cv2.imread("training/D/da 1.jpeg").shape

train = ImageDataGenerator(rescale = 1/255)

validation = ImageDataGenerator(rescale = 1/255)

train_dataset = train.flow_from_directory('training/',
                                          target_size = (200,200),
                                          batch_size = 3,
                                          class_mode = 'binary')

validation_dataset = validation.flow_from_directory('validation/',
                                                   target_size = (200,200),
                                                   batch_size = 3,
                                                   class_mode = 'binary')

train_dataset.class_indices

train_dataset.classes

model = tf.keras.models.Sequential([tf.keras.layers.Conv2D(16,(3,3),activation = 'relu',input_shape = (200,200,3)),
                                   # MaxPooling layer with pool size (2, 2)
                                    tf.keras.layers.MaxPool2D(2,2),
                                   # Convolutional layer with 32 filters, each of size (3, 3), and ReLU activation
                                    tf.keras.layers.Conv2D(32,(3,3),activation = 'relu'),
                                    tf.keras.layers.MaxPool2D(2,2),
                                   # Convolutional layer with 64 filters, each of size (3, 3), and ReLU activation
                                    tf.keras.layers.Conv2D(64,(3,3),activation = 'relu'),
                                    tf.keras.layers.MaxPool2D(2,2),
                                   # Flatten layer to convert 3D feature maps to 1D feature vectors
                                    tf.keras.layers.Flatten(),
                                   # Dense (fully connected) layer with 512 units and ReLU activation
                                    tf.keras.layers.Dense(512,activation = 'relu'),
                                   # Output layer with 1 unit and sigmoid activation for binary classification
                                    tf.keras.layers.Dense(1,activation = 'sigmoid')
                                    ])

model.compile(loss = 'binary_crossentropy',
              optimizer = RMSprop(lr=0.001),
              metrics = ['accuracy'])



model_fit = model.fit(train_dataset,
                      steps_per_epoch = 5,
                      epochs = 30,
                      validation_data = validation_dataset)


validation_dataset.class_indices

dir_path = 'testing/'

for i in os.listdir(dir_path):
    # Load the image and resize it to the target size
  img = image.load_img(dir_path+ i,target_size=(200,200))
  # Display the image using matplotlib
  plt.imshow(img)
  plt.show()

  # Convert the image to a NumPy array and add an extra dimension
  X = image.img_to_array(img)
  X = np.expand_dims(X,axis = 0)
# Stack the array vertically to create a batch of images
  images = np.vstack([X])
# Make a prediction using the trained model
  val = model.predict(images)
# Check the predicted value and print the corresponding class label
  if val == 0:
    print("This is Letter 'Da' in Sinhala")
  else:
    print("This is Letter 'Ya' in Sinhala")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Found 100 images belonging to 2 classes.
# Found 100 images belonging to 2 classes.
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.RMSprop.
# Epoch 1/30
# 5/5 [==============================] - 50s 12s/step - loss: 3.1385 - accuracy: 0.5333 - val_loss: 0.8939 - val_accuracy: 0.5000
# Epoch 2/30
# 5/5 [==============================] - 7s 1s/step - loss: 0.8152 - accuracy: 0.4000 - val_loss: 0.6820 - val_accuracy: 0.5700
# Epoch 3/30
# 5/5 [==============================] - 6s 1s/step - loss: 0.7694 - accuracy: 0.6923 - val_loss: 0.6503 - val_accuracy: 0.5200
# Epoch 4/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.6318 - accuracy: 0.5333 - val_loss: 0.5192 - val_accuracy: 0.6900
# Epoch 5/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.8563 - accuracy: 0.5333 - val_loss: 0.4675 - val_accuracy: 0.9600
# Epoch 6/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.3404 - accuracy: 0.9333 - val_loss: 0.2160 - val_accuracy: 0.9000
# Epoch 7/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.1697 - accuracy: 0.9333 - val_loss: 0.2329 - val_accuracy: 0.8900
# Epoch 8/30
# 5/5 [==============================] - 7s 2s/step - loss: 0.2475 - accuracy: 0.8667 - val_loss: 0.2189 - val_accuracy: 0.8900
# Epoch 9/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.2502 - accuracy: 0.8667 - val_loss: 0.5013 - val_accuracy: 0.7200
# Epoch 10/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.1080 - accuracy: 0.9333 - val_loss: 0.1374 - val_accuracy: 0.9500
# Epoch 11/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.1794 - accuracy: 0.9333 - val_loss: 0.1107 - val_accuracy: 0.9500
# Epoch 12/30
# 5/5 [==============================] - 6s 1s/step - loss: 0.0157 - accuracy: 1.0000 - val_loss: 0.1001 - val_accuracy: 0.9600
# Epoch 13/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.5218 - accuracy: 0.8000 - val_loss: 0.2180 - val_accuracy: 1.0000
# Epoch 14/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.0923 - accuracy: 1.0000 - val_loss: 0.1899 - val_accuracy: 0.9000
# Epoch 15/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.3454 - accuracy: 0.8667 - val_loss: 0.0465 - val_accuracy: 1.0000
# Epoch 16/30
# 5/5 [==============================] - 6s 1s/step - loss: 0.0146 - accuracy: 1.0000 - val_loss: 0.0383 - val_accuracy: 0.9900
# Epoch 17/30
# 5/5 [==============================] - 7s 2s/step - loss: 0.0620 - accuracy: 0.9333 - val_loss: 0.0170 - val_accuracy: 1.0000
# Epoch 18/30
# 5/5 [==============================] - 4s 981ms/step - loss: 0.0310 - accuracy: 1.0000 - val_loss: 0.0106 - val_accuracy: 1.0000
# Epoch 19/30
# 5/5 [==============================] - 7s 2s/step - loss: 0.0123 - accuracy: 1.0000 - val_loss: 0.0044 - val_accuracy: 1.0000
# Epoch 20/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.0061 - val_accuracy: 1.0000
# Epoch 21/30
# 5/5 [==============================] - 6s 1s/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0034 - val_accuracy: 1.0000
# Epoch 22/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 23/30
# 5/5 [==============================] - 5s 1s/step - loss: 1.3600e-04 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 24/30
# 5/5 [==============================] - 6s 1s/step - loss: 5.7612e-05 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 25/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0160 - val_accuracy: 0.9900
# Epoch 26/30
# 5/5 [==============================] - 8s 2s/step - loss: 2.0829e-04 - accuracy: 1.0000 - val_loss: 0.0037 - val_accuracy: 1.0000
# Epoch 27/30
# 5/5 [==============================] - 4s 980ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0087 - val_accuracy: 0.9900
# Epoch 28/30
# 5/5 [==============================] - 5s 1s/step - loss: 2.8779e-04 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 29/30
# 5/5 [==============================] - 6s 1s/step - loss: 3.0218e-04 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 30/30
# 5/5 [==============================] - 7s 2s/step - loss: 8.2371e-05 - accuracy: 1.0000 - val_loss: 0.0035 - val_accuracy: 1.0000
# 1/1 [==============================] - 0s 128ms/step
# This is Letter 'Ya' in Sinhala
# 1/1 [==============================] - 0s 36ms/step
# This is Letter 'Ya' in Sinhala
# 1/1 [==============================] - 0s 38ms/step
# This is Letter 'Ya' in Sinhala
# 1/1 [==============================] - 0s 34ms/step
# This is Letter 'Ya' in Sinhala
# 1/1 [==============================] - 0s 36ms/step
# This is Letter 'Ya' in Sinhala
# 1/1 [==============================] - 0s 38ms/step
# This is Letter 'Ya' in Sinhala
# 1/1 [==============================] - 0s 35ms/step
# This is Letter 'Ya' in Sinhala
# 1/1 [==============================] - 0s 34ms/step
# This is Letter 'Ya' in Sinhala
# 1/1 [==============================] - 0s 35ms/step
# This is Letter 'Ya' in Sinhala
# 1/1 [==============================] - 0s 53ms/step
# This is Letter 'Ya' in Sinhala
# 1/1 [==============================] - 0s 52ms/step
# This is Letter 'Ya' in Sinhala
# 1/1 [==============================] - 0s 58ms/step
# This is Letter 'Ya' in Sinhala
# 1/1 [==============================] - 0s 37ms/step
# This is Letter 'Ya' in Sinhala
# 1/1 [==============================] - 0s 34ms/step
# This is Letter 'Ya' in Sinhala
# 1/1 [==============================] - 0s 35ms/step
# This is Letter 'Ya' in Sinhala
# 1/1 [==============================] - 0s 37ms/step
# This is Letter 'Ya' in Sinhala
# 1/1 [==============================] - 0s 36ms/step
# This is Letter 'Ya' in Sinhala
# 1/1 [==============================] - 0s 38ms/step
# This is Letter 'Ya' in Sinhala
# 1/1 [==============================] - 0s 38ms/step
# This is Letter 'Ya' in Sinhala
# 1/1 [==============================] - 0s 35ms/step
# This is Letter 'Ya' in Sinhala
# 1/1 [==============================] - 0s 37ms/step
# This is Letter 'Da' in Sinhala
# 1/1 [==============================] - 0s 39ms/step
# This is Letter 'Da' in Sinhala
# 1/1 [==============================] - 0s 36ms/step
# This is Letter 'Da' in Sinhala
# 1/1 [==============================] - 0s 35ms/step
# This is Letter 'Da' in Sinhala
# 1/1 [==============================] - 0s 35ms/step
# This is Letter 'Da' in Sinhala
# 1/1 [==============================] - 0s 37ms/step
# This is Letter 'Da' in Sinhala
# 1/1 [==============================] - 0s 43ms/step
# This is Letter 'Da' in Sinhala
# 1/1 [==============================] - 0s 37ms/step
# This is Letter 'Da' in Sinhala
# 1/1 [==============================] - 0s 72ms/step
# This is Letter 'Da' in Sinhala
# 1/1 [==============================] - 0s 54ms/step
# This is Letter 'Da' in Sinhala
# 1/1 [==============================] - 0s 51ms/step
# This is Letter 'Da' in Sinhala
# 1/1 [==============================] - 0s 59ms/step
# This is Letter 'Da' in Sinhala
# 1/1 [==============================] - 0s 40ms/step
# This is Letter 'Da' in Sinhala
# 1/1 [==============================] - 0s 34ms/step
# This is Letter 'Da' in Sinhala
# 1/1 [==============================] - 0s 36ms/step
# This is Letter 'Da' in Sinhala
# 1/1 [==============================] - 0s 39ms/step
# This is Letter 'Da' in Sinhala
# 1/1 [==============================] - 0s 37ms/step
# This is Letter 'Da' in Sinhala
# 1/1 [==============================] - 0s 36ms/step
# This is Letter 'Da' in Sinhala
# 1/1 [==============================] - 0s 34ms/step
# This is Letter 'Da' in Sinhala
# 1/1 [==============================] - 0s 34ms/step
# This is Letter 'Da' in Sinhala
